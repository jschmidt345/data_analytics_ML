# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium

# %%
df = pd.read_csv('COVID-19 Cases.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# print(df.isna().sum() / len(df) * 100)
df1 = df.drop(['People_Total_Tested_Count', 'People_Hospitalized_Cumulative_Count'], axis=1)
cleaned_df = df1.dropna().sample(frac=1)
column_names = cleaned_df.columns

df_ny = df1[df1['Combined_Key'] == 'New York, New York, US']
# sns.heatmap(df1.isna())

# %%
ny_map = folium.Map(location=[40.713118, -73.932087,], 
                         zoom_starts=11,
                         titles='CartoDB dark_matter')

# %%
df_ny
# Out:
#         Case_Type   Cases  Difference       Date            Combined_Key  \
# 68031      Deaths       0           0  2/20/2020  New York, New York, US
# 68148      Deaths   21477          62  5/29/2020  New York, New York, US
# 74893   Confirmed       0           0  2/28/2020  New York, New York, US
# 75347      Deaths       0           0  2/29/2020  New York, New York, US
# 76762      Deaths       0           0   2/9/2020  New York, New York, US
# ...           ...     ...         ...        ...                     ...
# 910559     Deaths       0           0  2/24/2020  New York, New York, US
# 911976  Confirmed     269           0  3/15/2020  New York, New York, US
# 912051     Deaths      32          11  3/17/2020  New York, New York, US
# 912786  Confirmed  187250        1127  5/13/2020  New York, New York, US
# 914136  Confirmed       0           0  2/16/2020  New York, New York, US
#
#        Country_Region Province_State    Admin2 iso2 iso3     FIPS        Lat  \
# ...

# %%
df_ny
# Out:
#         Case_Type   Cases  Difference       Date            Combined_Key  \
# 68031      Deaths       0           0  2/20/2020  New York, New York, US
# 68148      Deaths   21477          62  5/29/2020  New York, New York, US
# 74893   Confirmed       0           0  2/28/2020  New York, New York, US
# 75347      Deaths       0           0  2/29/2020  New York, New York, US
# 76762      Deaths       0           0   2/9/2020  New York, New York, US
# ...           ...     ...         ...        ...                     ...
# 910559     Deaths       0           0  2/24/2020  New York, New York, US
# 911976  Confirmed     269           0  3/15/2020  New York, New York, US
# 912051     Deaths      32          11  3/17/2020  New York, New York, US
# 912786  Confirmed  187250        1127  5/13/2020  New York, New York, US
# 914136  Confirmed       0           0  2/16/2020  New York, New York, US
#
#        Country_Region Province_State    Admin2 iso2 iso3     FIPS        Lat  \
# ...

# %%
for i in range(len(df_ny)):
    lat = df_ny['Lat'].iloc[i]
    print(lat)
    long = df_ny['Long'].iloc[i]
    popup_text = """
                 Population {}<br>
                 """
    popup_text = popup_text.format(df_ny.index[i],
                                   df_ny.iloc[i][-1],
                                   df_ny.iloc[i][-2])
    folium.CircleMarker(location=[lat, long], popup=popup_text,
                        fill=True).add_to(chicago_map)
# Out:
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# 40.767272600000005
# ...

# %%
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# 40.767272600000005
