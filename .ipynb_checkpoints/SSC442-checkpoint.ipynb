# %% [markdown]
# # Determining Valuable Emerging Markets
# - ### Goal 1:
#
#     * #### Create a supervised learning model
#
#         1. Must implement a target system: classify success: e.g. if inflation is < 2%, target = 1
#         2. Train model on Asian data, apply to African
#         3. Analyze results
#
# **goal of model needs work, maybe switch to regression or find another idea**
#
# **as of right now would like df with target, as i am not familiar with creating arbitrary targets**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# write code that takes aggregates all the data for single country, without have to do it manually
import os
os.getcwd()
# Out:
# '/Users/jschmidt345/Code/data_analytics_ml'

# %%
asian_country_names = ['China','Hong Kong','Japan','Macau','Mongolia','North Korea', 'South Korea','Taiwan','Sri Lanka','India','Bangladesh','Bhutan','Nepal','Pakistan','The Maldives']

# %%
# importing and shuffling data
df = pd.read_csv('/Users/jschmidt345/f9ac7dba-eefe-47a7-a044-007a76efff06_Data.csv', delimiter=',')
df_shuffled = df[df['Country Name'].isin(asian_country_names)].sample(frac=1)

# analyzing data types and df characteristics
## big issue: every row has some missing data, so if you try to drop rows with na/empty, there will be no data left

df_shuffled.isin(['..'])
df_shuffled[df_shuffled.isin(['..'])]

## you can drop na's easily, though. 

# df = df.dropna()
# df = df.drop(df[df.isin(['..'])].index)

# trying to find the feature columns with the least amount of nans
column_names = df.columns
for i in column_names:
    print(df[i].isin(['..']).sum())
    print(i)

# from quick loop, looks as tho we should use anything <1000
# e.g. current account, ***
# Out:
# 0
# Country Name
# 0
# Country Code
# 0
# Time
# 0
# Time Code
# 1433
# Start-up procedures to register a business, male (number) [IC.REG.PROC.MA]
# 525
# Current account balance (% of GDP) [BN.CAB.XOKA.GD.ZS]
# 686
# Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]
# 967
# Adjusted net national income (annual % growth) [NY.ADJ.NNTY.KD.ZG]
# 995
# Adjusted net national income per capita (constant 2010 US$) [NY.ADJ.NNTY.PC.KD]
# 2189
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+) [FX.OWN.TOTL.ZS]
# 2059
# GINI index (World Bank estimate) [SI.POV.GINI]
# 2263
# Ease of doing business index (1=most business-friendly regulations) [IC.BUS.EASE.XQ]
# 2270
# Human capital index (HCI) (scale 0-1) [HD.HCI.OVRL]
# 610
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.ZS]
# 667
# ...

# %% [markdown]
# # End of 5/28/20
# ### Thoughts:
# 1. Hoping to Isolate a few columns that have the most data
#     - as it is now, too much missing data
#     - if isolating leaves enough data, can proceed

# %%
ca = []
fdi = []
inf = []

for i in range(len(df['Current account balance (% of GDP) [BN.CAB.XOKA.GD.ZS]'])):
    ca.append(df['Current account balance (% of GDP) [BN.CAB.XOKA.GD.ZS]'][i])
    fdi.append(df['Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]'][i])
    inf.append(df['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]'][i])
#     if df[df['Country Name'] == 'Nepal']['Start-up procedures to register a business, male (number) [IC.REG.PROC.MA]'][i] == '..':
#         print(i)
#         df[df['Country Name'] == 'Nepal']['Start-up procedures to register a business, male (number) [IC.REG.PROC.MA]'][i] = 0.00
#         print(df[df['Country Name'] == 'Nepal']['Start-up procedures to register a business, male (number) [IC.REG.PROC.MA]'])
    

        

for index, item in enumerate(ca):
    if (item == '..'):
        ca[index] = 0
    else:
        ca[index] = float(ca[index])
df['Current account balance (% of GDP) [BN.CAB.XOKA.GD.ZS]'] = ca


for index, item in enumerate(fdi):
    if (item == '..'):
        fdi[index] = 0
    else:
        fdi[index] = float(fdi[index])
df['Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]'] = fdi


for index, item in enumerate(inf):
    if (item == '..'):
        inf[index] = 0
    else: 
        inf[index] = float(inf[index])
df['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]'] = inf
df[df['Country Name'] == 'China']
# Out:
#    Country Name Country Code    Time Time Code  \
# 40        China          CHN  1980.0    YR1980
# 41        China          CHN  1981.0    YR1981
# 42        China          CHN  1982.0    YR1982
# 43        China          CHN  1983.0    YR1983
# 44        China          CHN  1984.0    YR1984
# 45        China          CHN  1985.0    YR1985
# 46        China          CHN  1986.0    YR1986
# 47        China          CHN  1987.0    YR1987
# 48        China          CHN  1988.0    YR1988
# 49        China          CHN  1989.0    YR1989
# 50        China          CHN  1990.0    YR1990
# 51        China          CHN  1991.0    YR1991
# 52        China          CHN  1992.0    YR1992
# 53        China          CHN  1993.0    YR1993
# 54        China          CHN  1994.0    YR1994
# 55        China          CHN  1995.0    YR1995
# 56        China          CHN  1996.0    YR1996
# 57        China          CHN  1997.0    YR1997
# 58        China          CHN  1998.0    YR1998
# ...

# %%
DataFrameDictAsia = {elem : pd.DataFrame for elem in asian_country_names}
for key in DataFrameDictAsia.keys():
    DataFrameDictAsia[key] = df[:][df['Country Name'] == key]

# %%
indicator_list = ['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]', 'Current account balance (% of GDP) [BN.CAB.XOKA.GD.ZS]', 'Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]']

# %%
pakistan = DataFrameDictAsia['Pakistan']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
pakistan
# Out:
# 440    11.938231
# 441    11.879914
# 442     5.903529
# 443     6.362033
# 444     6.087167
# 445     5.614839
# 446     3.506414
# 447     4.681219
# 448     8.837937
# 449     7.844265
# 450     9.052132
# 451    11.791270
# 452     9.509041
# 453     9.973665
# 454    12.368194
# 455    12.343579
# 456    10.373809
# 457    11.375493
# 458     6.228004
# 459     4.142637
# 460     4.366665
# 461     3.148261
# 462     3.290345
# 463     2.914135
# 464     7.444625
# 465     9.063327
# 466     7.921084
# 467     7.598684
# 468    20.286121
# 469    13.647765
# 470    13.881139
# 471    11.916769
# 472     9.682352
# 473     7.692156
# 474     7.189384
# 475     2.529328
# 476     3.765119
# 477     4.085374
# 478     5.078057
# 479     0.000000
# Name: Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG], dtype: float64

# %%
means_asian = {}
DataFrameDict1['Seychelles']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]'] = DataFrameDict1['Seychelles']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]'].astype(float) 
sum(DataFrameDict1['Seychelles']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]'])

#### MASS comvert to float using above method, but with loop
# similar to above
for key in DataFrameDictAsia.keys():
    for item in indicator_list:
                pass
            
            

DataFrameDictAsia['Nepal']['Foreign direct investment, net (BoP, current US$) [BN.KLT.DINV.CD]']

china = DataFrameDictAsia['China']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
hk = DataFrameDictAsia['Hong Kong']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
jp = DataFrameDictAsia['Japan']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
macau = DataFrameDictAsia['Macau']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
mongolia = DataFrameDictAsia['Mongolia']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
nk = DataFrameDictAsia['North Korea']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
sk = DataFrameDictAsia['South Korea']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
taiwan = DataFrameDictAsia['Taiwan']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
sri_lanka = DataFrameDictAsia['Sri Lanka']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
india = DataFrameDictAsia['India']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
bangladesh =  DataFrameDictAsia['Bangladesh']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
bhutan = DataFrameDictAsia['Bhutan']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
nepal = DataFrameDictAsia['Nepal']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
pakistan = DataFrameDictAsia['Pakistan']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
maldives = DataFrameDictAsia['The Maldives']['Inflation, consumer prices (annual %) [FP.CPI.TOTL.ZG]']
lsss = [np.mean(china), np.mean(hk), np.mean(jp), np.mean(macau), np.mean(mongolia), np.mean(nk), np.mean(sk), np.mean(taiwan), np.mean(sri_lanka), np.mean(india), np.mean(bangladesh), np.mean(bhutan), np.mean(nepal), np.mean(pakistan), np.mean(maldives)]


# china(4.16), jp(.98), mongolia(15),sri(9.9), india(7.9), bang(5.03), bhutan(6.49), nepal(8.01) ,pakistan (7.88)







del lsss[1]
lsss
del lsss[2]
lsss
del lsss[3 : 5]
lsss
del lsss[3]
lsss
del lsss[-1]
bin_list = lsss
sorted(bin_list)
# j
# Out:
# [0.9879540511627507,
#  4.161500901874299,
#  5.038313621742917,
#  6.49022479679793,
#  7.882851563621753,
#  7.902614368597208,
#  8.014598657217647,
#  9.905391640329125,
#  15.793740940927242]

# %%
## for each inidcator, whoever has the largest avg(fdi, ca) or smallest(inf) 
## top 5 get 1s, bottom 10 get 0s



DataFrameDictAsia.update({
    
})
